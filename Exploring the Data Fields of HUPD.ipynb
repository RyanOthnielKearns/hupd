# %% [markdown]
# # Harvard USPTO Patent Dataset (HUPD)

# %% [markdown]
# ## Exploring the Dataset

# %% [markdown]
# In this tutorial, we use the bibliographic metadata of the HUPD to obtain some of its descriptive statistics.

# %%
## Import relevant libraries and dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Data Frame

# %% [markdown]
# First thing first: Let's use `pd.read_feather` to load the bibliographic metadata.

# %%
# Specify the metadata path
_METADATA_PATH = "./mnt/data/HUPD/metadata-2021-02-10.feather"
# Read the feather
df = pd.read_feather(_METADATA_PATH)

# %% [markdown]
# We can see how the dataframe looks like.

# %%
# Display the pandas dataframe
df
# Out:
#         application_number filing_date application_invention_type  \
# 0                 10000645  2001-11-15                    Utility
# 1                 10000771  2001-10-31                    Utility
# 2                 10000973  2001-10-30                    Utility
# 3                 10000997  2001-11-30                    Utility
# 4                 10001095  2001-11-15                    Utility
# ...                    ...         ...                        ...
# 4572533           16062170  2018-06-14                    Utility
# 4572534           16062262  2018-06-14                    Utility
# 4572535           16062675  2018-06-15                    Utility
# 4572536           16062981  2018-06-15                    Utility
# 4572537           16064534  2018-06-21                    Utility
#
#               examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0               ELISCA, PIERRE E              3621        705        057000
# 1                DOVE, TRACY MAE              1795        429        013000
# 2             SCHAETZLE, KENNEDY              3766        607        017000
# 3        FREDMAN, JEFFREY NORMAN              1637        536        023100
# 4                  LIN, SHEW FEN              2166        707        102000
# ...                          ...               ...        ...           ...
# 4572533         JOHNSON, STEPHEN              3641      102.0        202120
# 4572534       LACHICA, ERICSON M              1792      426.0        115000
# 4572535         VERLEY, NICOLE T              3618      280.0        730200
# 4572536         JAVANMARD, SAHAR              1627      514.0        560000
# 4572537            LIANG, SHIBIN              1741      425.0        141000
#
#          confirm_number atty_docket_number  \
# 0                9500.0          4208-4051
# 1                8132.0         PUG.0065US
# 2                1868.0          P-9572.00
# 3                4960.0          D1550-1US
# 4                9485.0          SBL0011US
# ...                 ...                ...
# 4572533          5068.0  8952-000475-US-NP
# 4572534          8265.0       7066-X18-099
# 4572535          9465.0  8952-000477-US-NP
# 4572536          2734.0    SCIAD-34717.252
# 4572537          6310.0          45079.142
#
#                                           appl_status_desc  ...  \
# 0                                            Patented Case  ...
# 1                    Abandoned -- Failure to Pay Issue Fee  ...
# 2        Abandoned -- Failure to Respond to an Office A...  ...
# 3                                            Patented Case  ...
# 4                                            Patented Case  ...
# ...                                                    ...  ...
# 4572533                                      Patented Case  ...
# 4572534                            Non Final Action Mailed  ...
# 4572535  Response after Final Action Forwarded to Examiner  ...
# 4572536                            Non Final Action Mailed  ...
# 4572537                            Non Final Action Mailed  ...
#
#         old_uspc_subclass examiner_id examiner_name_last examiner_name_first  \
# 0                  057000     99434.0             ELISCA              PIERRE
# 1                  013000     67580.0               DOVE               TRACY
# 2                  017000     92488.0          SCHAETZLE             KENNEDY
# 3                  023100     88290.0            FREDMAN             JEFFREY
# 4                  102000     98557.0                LIN            SHEW FEN
# ...                   ...         ...                ...                 ...
# 4572533              None         NaN               None                None
# 4572534              None         NaN               None                None
# 4572535              None         NaN               None                None
# 4572536              None         NaN               None                None
# 4572537              None         NaN               None                None
#
#         examiner_name_middle  old_status patent_year    status  decision  \
# 0                          E    ACCEPTED        2004   PENDING   PENDING
# 1                        MAE    REJECTED        2010  REJECTED  REJECTED
# 2                       None    REJECTED        2005  REJECTED  REJECTED
# 3                     NORMAN    ACCEPTED        2006  ACCEPTED  ACCEPTED
# 4                       None    ACCEPTED        2007  ACCEPTED  ACCEPTED
# ...                      ...         ...         ...       ...       ...
# 4572533                 None     PENDING        2018  ACCEPTED  ACCEPTED
# 4572534                 None     PENDING        2018   PENDING   PENDING
# 4572535                 None     PENDING        2018  ACCEPTED  ACCEPTED
# 4572536                 None     PENDING        2018  ACCEPTED  ACCEPTED
# 4572537                 None     PENDING        2018  ACCEPTED  ACCEPTED
#
#         foreign
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 4572533       1
# 4572534       1
# 4572535       1
# 4572536       1
# 4572537       1
#
# [4572538 rows x 47 columns]

# %%
df["decision"].unique()
# Out:
# array(['PENDING', 'REJECTED', 'ACCEPTED', 'CONT-ACCEPTED', 'CONT-PENDING',
#        'CONT-REJECTED'], dtype=object)

# %%
sample_df = df.loc[df["application_number"].isin([
  "10465416",
  "10488451",
  "10488662",
  "10494861",
  "10499494",
  "10505992",
  "10519008",
  "10519960",
  "10536974",
  "10545356",
  ])].reset_index().drop(columns=["index"])
sample_df
# Out:
#   application_number filing_date application_invention_type  \
# 0           10465416  2003-06-18                    Utility
# 1           10488451  2004-03-03                    Utility
# 2           10488662  2004-03-04                    Utility
# 3           10494861  2004-10-07                    Utility
# 4           10499494  2004-07-19                    Utility
# 5           10505992  2004-10-07                    Utility
# 6           10519008  2004-12-21                    Utility
# 7           10519960  2005-08-30                    Utility
# 8           10536974  2005-12-23                    Utility
# 9           10545356  2006-11-20                    Utility
#
#              examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0               KOSLOW, CAROL M              1755        106        035000
# 1             BETTON, TIMOTHY E              1617        424        489000
# 2             RUSSEL, JEFFREY E              1654        514        012000
# 3             SIMONE, TIMOTHY F              1761       99.0        453000
# 4             PILKINGTON, JAMES              3682       74.0        422000
# 5              KASTLER, SCOTT R              1793      266.0        135000
# 6  ALSTRUM ACEVEDO, JAMES HENRY              1616      514.0        179000
# 7          WOLFE JR, WILLIS RAY              3747      701.0        108000
# 8          NICOLAS, FREDERICK C              3754      222.0        399000
# 9             THOMAS, TIMOTHY P              1628      514.0        450000
#
#    confirm_number         atty_docket_number  \
# 0          5024.0                      95656
# 1          3724.0   20967 US C038435/0175484
# 2          6416.0                    MER-127
# 3          8787.0                  015090US1
# 4          9267.0                     F-8292
# 5          3555.0                   04571/HG
# 6          7228.0            019904-002210US
# 7          5416.0                  10537/286
# 8          6214.0  6.70.1067 PCT/IB-US (LBT1
# 9          3312.0                        nan
#
#                                     appl_status_desc  ... old_uspc_subclass  \
# 0                                      Patented Case  ...            035000
# 1  Abandoned -- Failure to Respond to an Office A...  ...            489000
# 2  Abandoned -- Failure to Respond to an Office A...  ...            012000
# 3                                      Patented Case  ...            453000
# 4  Patent Expired Due to NonPayment of Maintenanc...  ...            422000
# 5  Patent Expired Due to NonPayment of Maintenanc...  ...            135000
# 6                                      Patented Case  ...            179000
# 7  Patent Expired Due to NonPayment of Maintenanc...  ...            108000
# 8                                      Patented Case  ...            399000
# 9                                      Patented Case  ...            450000
#
#   examiner_id examiner_name_last examiner_name_first examiner_name_middle  \
# 0     95539.0             KOSLOW               CAROL                    M
# 1     59706.0             BETTON             TIMOTHY                    E
# 2     73069.0             RUSSEL             JEFFREY                    E
# 3     61615.0             SIMONE             TIMOTHY                    F
# 4     76523.0         PILKINGTON               JAMES                 None
# 5     65269.0            KASTLER               SCOTT                    R
# 6     66663.0    ALSTRUM ACEVEDO               JAMES                HENRY
# 7     57541.0           WOLFE JR              WILLIS                  RAY
# 8     99781.0            NICOLAS           FREDERICK                    C
# 9     66987.0             THOMAS             TIMOTHY                    P
#
#    old_status patent_year         status       decision foreign
# 0    ACCEPTED        2005  CONT-ACCEPTED  CONT-ACCEPTED       0
# 1    REJECTED        2004       REJECTED       REJECTED       1
# 2    REJECTED        2005       REJECTED       REJECTED       1
# 3    ACCEPTED        2005       ACCEPTED       ACCEPTED       1
# 4    ACCEPTED        2005       ACCEPTED       ACCEPTED       1
# 5    ACCEPTED        2005       ACCEPTED       ACCEPTED       1
# 6    ACCEPTED        2006       ACCEPTED       ACCEPTED       1
# 7    ACCEPTED        2005        PENDING        PENDING       1
# 8    ACCEPTED        2006        PENDING        PENDING       1
# 9    ACCEPTED        2007       ACCEPTED       ACCEPTED       1
#
# [10 rows x 47 columns]

# %%
sample_df.to_feather("sample_metadata.feather")

# %% [markdown]
# We can also display all the data fields within the dataframe.

# %%
# Let's look at the columns of the dataframe
df.columns
# Out:
# Index(['application_number', 'filing_date', 'application_invention_type',
#        'examiner_full_name', 'examiner_art_unit', 'uspc_class',
#        'uspc_subclass', 'confirm_number', 'atty_docket_number',
#        'appl_status_desc', 'appl_status_date', 'file_location',
#        'file_location_date', 'earliest_pgpub_number', 'earliest_pgpub_date',
#        'wipo_pub_number', 'wipo_pub_date', 'patent_number',
#        'patent_issue_date', 'invention_title', 'small_entity_indicator',
#        'aia_first_to_file', 'publication_number', 'date_produced',
#        'date_published', 'old_decision', 'old_title', 'main_cpc_label',
#        'cpc_labels', 'main_ipcr_label', 'ipcr_labels', 'old_filing_date',
#        'temp_patent_number', 'old_patent_issue_date', 'old_abandon_date',
#        'title_uspto', 'old_uspc_class', 'old_uspc_subclass', 'examiner_id',
#        'examiner_name_last', 'examiner_name_first', 'examiner_name_middle',
#        'old_status', 'patent_year', 'status', 'decision', 'foreign'],
#       dtype='object')

# %% [markdown]
# We can try to display all the patent applications that were filed to the USPTO in the year 2016.

# %%
# Display all the USPTO patent applications that were filed in 2016 according to our metadata
df[df.filing_date.astype(str).str.startswith('2016')]
# Out:
#         application_number filing_date application_invention_type  \
# 2237196           13144833  2016-01-22                    Utility
# 2339357           13261748  2016-01-20                    Utility
# 2448141           13383015  2016-02-01                    Utility
# 2562145           13510522  2016-02-03                    Utility
# 2622093           13577188  2016-02-19                    Utility
# ...                    ...         ...                        ...
# 4351788           15530689  2016-03-31                    Utility
# 4351789           15530690  2016-12-09                    Utility
# 4351791           15530698  2016-04-15                    Utility
# 4351799           15530795  2016-05-02                    Utility
# 4360405           15540283  2016-07-07                    Utility
#
#          examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 2237196  FUBARA, BLESSING M              1613        424        059000
# 2339357      LEUNG, WAI LUN              2637      398.0        045000
# 2448141  MICHENER, JOSHUA J              3635        052        282100
# 2562145         CHIN, HUI H              1762        524        318000
# 2622093   TRISCHLER, JOHN T              2859        320        119000
# ...                     ...               ...        ...           ...
# 4351788   OLSHANNIKOV, ALEX              2142        715        763000
# 4351789        WONG, YUEN H              3667        701        036000
# 4351791         YAARY, ERIC              1747        131        352000
# 4351799    PENG, CHARLIE YU              3649        116        02800R
# 4360405     DANIEL, LAURA M              1624        540        217000
#
#          confirm_number         atty_docket_number  \
# 2237196          9423.0  096115-0897066 (002510US)
# 2339357          5040.0                     169273
# 2448141          5412.0                   0401-015
# 2562145          9378.0               20162.54USWO
# 2622093          6303.0               3C101-050US1
# ...                 ...                        ...
# 4351788          5508.0          JAMD1147919(P016)
# 4351789          8430.0                106389-4216
# 4351791          5411.0              SWEDM.055AUS2
# 4351799          3114.0                        nan
# 4360405          7909.0               23994-US-PCT
#
#                                           appl_status_desc  ...  \
# 2237196  Abandoned -- Failure to Respond to an Office A...  ...
# 2339357                                      Patented Case  ...
# 2448141                                      Patented Case  ...
# 2562145                                      Patented Case  ...
# 2622093                                      Patented Case  ...
# ...                                                    ...  ...
# 4351788                            Non Final Action Mailed  ...
# 4351789                                      Patented Case  ...
# 4351791  Abandoned -- Failure to Respond to an Office A...  ...
# 4351799  Abandoned -- Failure to Respond to an Office A...  ...
# 4360405                                      Patented Case  ...
#
#         old_uspc_subclass examiner_id examiner_name_last examiner_name_first  \
# 2237196            059000     75390.0             FUBARA            BLESSING
# 2339357            045000     95191.0              LEUNG                 WAI
# 2448141            282100     92927.0           MICHENER              JOSHUA
# 2562145            318000     92253.0               CHIN                 HUI
# 2622093            119000     94632.0          TRISCHLER                JOHN
# ...                   ...         ...                ...                 ...
# 4351788            763000     65672.0        OLSHANNIKOV                ALEX
# 4351789            036000     97221.0               WONG                YUEN
# 4351791            352000     67695.0              YAARY                ERIC
# 4351799            02800R     70437.0               PENG             CHARLIE
# 4360405            217000     82332.0             DANIEL               LAURA
#
#         examiner_name_middle  old_status patent_year    status  decision  \
# 2237196                    M    REJECTED        2016  REJECTED  REJECTED
# 2339357                  LUN    ACCEPTED        2016  ACCEPTED  ACCEPTED
# 2448141                    J    ACCEPTED        2016  ACCEPTED  ACCEPTED
# 2562145                    H    ACCEPTED        2012  ACCEPTED  ACCEPTED
# 2622093                    T    ACCEPTED        2013  ACCEPTED  ACCEPTED
# ...                      ...         ...         ...       ...       ...
# 4351788                 None     PENDING        2018  ACCEPTED  ACCEPTED
# 4351789                    H     PENDING        2018   PENDING   PENDING
# 4351791                 None     PENDING        2018  REJECTED  REJECTED
# 4351799                   YU     PENDING        2017  REJECTED  REJECTED
# 4360405                    M     PENDING        2018  ACCEPTED  ACCEPTED
#
#         foreign
# 2237196       1
# 2339357       1
# 2448141       1
# 2562145       1
# 2622093       1
# ...         ...
# 4351788       0
# 4351789       0
# 4351791       0
# 4351799       0
# 4360405       1
#
# [373256 rows x 47 columns]

# %% [markdown]
# ## Statistics about the Decision Status Labels

# %% [markdown]
# We might be interested in learning about the distribution of the accepted and rejected patent applications in the dataset. To that end, let's look at the total number of accepted, rejected, pending, cont-accepted, cont-rejected, and cont-pending patent applications between 2004 and 2018.

# %%
# Let's look at the distribution of the decision status labels
status_stats = (df.status).value_counts().to_dict()
print(status_stats)
# Out:
# {'ACCEPTED': 1857090, 'REJECTED': 1092092, 'CONT-ACCEPTED': 656028, 'PENDING': 488920, 'CONT-REJECTED': 288709, 'CONT-PENDING': 189699}

# %% [markdown]
# In fact, we can plot these numbers in a nice way using `matplotlib`.

# %%
# Let's plot the numbers above
plt.figure(figsize=(10, 6))
plt.bar(range(len(status_stats)), list(status_stats.values()), align='center')
plt.xticks(range(len(status_stats)), list(status_stats.keys()))

# Specify the x-label, y-label, and title
plt.xlabel('Decision Status Labels', fontsize=14)
plt.ylabel('Number of Patent Applications', fontsize=14)
plt.title('Distribution of Decision Status Labels over Time', fontsize=16) 
plt.show()

# %% [markdown]
# ## Statistics about the IPC/CPC Labels

# %% [markdown]
# How about the distribution of the IPC/CPC labels?

# %%
# Let's restrict our attention to the IPC/CPC labels at the subclass level
df['cpc_sub'] = df.cpc_labels.str[:4]
df['ipc_sub'] = df.main_ipcr_label.str[:4]

# %%
# Unique IPCR subclass labels
print(f'# Unique IPCs: {len(df.ipc_sub.value_counts())}')
print(f'# Unique CPCs: {len(df.cpc_sub.value_counts())}')
# Out:
# # Unique IPCs: 638
# # Unique CPCs: 627

# %% [markdown]
# Let's explore the distribution of IPC labels at the subclass level.

# %%
# Note that we also have some patent applications that do not contain IPC/CPC labels
df.ipc_sub.value_counts()
# Out:
# G06F    444122
#         288832
# H01L    236711
# A61K    191050
# H04L    144278
#          ...
# C13C         1
# F99Z         1
# F24T         1
# C06F         1
# F24V         1
# Name: ipc_sub, Length: 638, dtype: int64

# %% [markdown]
# Interesting... did you realize that the first column of the second row is empty? This implies that there are some patent applications that do not have any IPC labels.

# %% [markdown]
# ### Creating the Two Plots in Figure 2 of the Paper (Distribution of Accepted Patent Applications from 2011 to 2016)

# %% [markdown]
# Let's now try to re-cerate the two plots in Figure 2.

# %%
# Import additional libraries and dependencies for some of the computations below
from __future__ import division
from itertools import *
from pylab import *

# %% [markdown]
# We restrict our attention to all the patent applications that were filed to the PTO between 2011 and 2016 (inclusive) and that contain the label "ACCEPTED" in their decision status field.

# %%
# Start and end dates (2011-2016)
start_date = '2011-01-01'
end_date = '2016-12-31'

# Filter the dataframe by the specific ranges
df_2011_2016 = df[df['filing_date'] >= start_date]
df_2011_2016 = df_2011_2016[df_2011_2016['filing_date'] <= end_date]

# Consider the patent applications that have the 'ACCEPTED' decision status label
accepted_df_2011_2016 = df_2011_2016[df_2011_2016.status == 'ACCEPTED']

# %%
# Accepted patent applications from 2011 to 2016 
accepted_df_2011_2016_ipc_sub = accepted_df_2011_2016.ipc_sub.value_counts().to_dict()

# For IPC
values = list(accepted_df_2011_2016_ipc_sub.values())
labels = list(accepted_df_2011_2016_ipc_sub.keys())

# %%
# We have one patent application that doesn't have an IPC subclass label in our restricted collection
for i, elt in enumerate(labels):
    if len(elt) != 4:
        print(values[i])

# %%
# Let's display this patent application which is missing its IPC subclass label
accepted_df_2011_2016[accepted_df_2011_2016.ipc_sub == '']
# Out:
#       application_number filing_date application_invention_type  \
# 26977           10510786  2012-02-06                    Utility
#
#       examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 26977    BILODEAU, DAVID              2648      455.0        063100
#
#        confirm_number atty_docket_number  \
# 26977          4317.0     2002P00270WOUS
#
#                                         appl_status_desc  ...  \
# 26977  Patent Expired Due to NonPayment of Maintenanc...  ...
#
#       examiner_name_last examiner_name_first examiner_name_middle old_status  \
# 26977           BILODEAU               DAVID                 None   ACCEPTED
#
#       patent_year    status  decision foreign cpc_sub ipc_sub
# 26977        2005  ACCEPTED  ACCEPTED       1
#
# [1 rows x 49 columns]

# %% [markdown]
# In the upcoming parts, we focus only on the most popular 19 IPC sublcass codes.

# %%
# Let's get the names and values of those top 19 IPC subclass labels and aggregate all the remaining IPC codes under the name "Other Labels" 
_THRESHOLD = 19
new_values = values[:_THRESHOLD]
new_labels = labels[:_THRESHOLD]
new_values.append(np.sum(values[_THRESHOLD:]))
new_labels.append('Other Labels')

# %%
## Creating the pie char in Figure 2

# Now, let's plot the distribution of IPC categories of "accepted" patent applications from 2011 to 2016 (Figure 2 in the paper)
fig, ax = plt.subplots(figsize=(12, 12))

patches, texts, pcts = ax.pie(
    new_values, labels=new_labels, autopct=lambda pct: '{:.1f}%'.format(pct) if pct > 1.5 else '',
    wedgeprops={'linewidth': 2.5, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=60)
    
for i, patch in enumerate(patches):
  texts[i].set_color(patch.get_facecolor())
plt.setp(pcts, color='white')
plt.setp(texts, fontweight=6)
ax.set_title('Distribution of IPC Categories from 2011 to 2016', fontsize=22)
plt.tight_layout()
plt.savefig('figures/ipc_distrib.png')

# %%
## Creating the Zipf plot in Figure 2 ##

# We can also create the Zipf plot on the left side of Figure 2
fig, ax = plt.subplots(figsize=(12, 8))
ranks = arange(1, len(values)+1)
loglog(ranks, values, marker=".")

ax.set_title('Zipf Plot for the Distribution of the IPC Categories from 2011 to 2016', fontsize=16)
ax.set_xlabel("Frequency Rank of the IPC Subclass Code", fontsize=14)
ax.set_ylabel("Absolute Frequency of the IPC Subclass Code", fontsize=14)
ax.grid(False)

for n in list(logspace(-0.5, log10(len(values)), 20).astype(int)):
    dummy = text(ranks[n], values[n], " " + labels[n], 
                 verticalalignment="bottom",
                 horizontalalignment="left", 
                 fontsize=12)

plt.tight_layout()
plt.savefig('figures/zipf_ipc_distrib.png')

# %% [markdown]
# ## Statistics about the Patent Examiners

# %% [markdown]
# So far, we have looked at the decision status and IPC subclass label distributions, but we can also look at the acceptance ratio of examiners using HUPD. Let's now explore the behaviours of the patent examiners at the PTO.

# %%
# Get the names of 100 patent examiners who examined the most patent applications by number
top100_examiner_names = list((df.examiner_full_name.value_counts()[:100]).keys())

# %%
# Create a temporary dataframe
examiner_dec_df = pd.DataFrame()

# For each examiner in the list above, determine the decisions made by that examiner and add it to the temporary dataframe
for examiner_name in top100_examiner_names:
    decision_stat_dict = ((df[df['examiner_full_name'] == examiner_name])['decision'].value_counts()).to_dict()
    decision_stat_dict['examiner_full_name'] = examiner_name
    examiner_dec_df = examiner_dec_df.append(decision_stat_dict, ignore_index=True)

# %%
# Now let's look at that dataframe
examiner_dec_df
# Out:
#     ACCEPTED  CONT-ACCEPTED  CONT-PENDING  CONT-REJECTED  PENDING  REJECTED  \
# 0     1025.0          299.0          62.0           77.0    218.0     380.0
# 1     1069.0          302.0          84.0           61.0    240.0     281.0
# 2     1153.0          302.0          71.0           44.0    281.0     184.0
# 3      937.0          299.0          85.0           89.0    246.0     311.0
# 4     1118.0          152.0          33.0           29.0    253.0     381.0
# ..       ...            ...           ...            ...      ...       ...
# 95     820.0          260.0          71.0           26.0    210.0      71.0
# 96     525.0          158.0          46.0           75.0    123.0     526.0
# 97     905.0          188.0          37.0           16.0    216.0      87.0
# 98     595.0          223.0          55.0           78.0    182.0     315.0
# 99     763.0          233.0          53.0           28.0    192.0     179.0
#
#    examiner_full_name
# 0     ALI, MOHAMMAD M
# 1      NGUYEN, HANH N
# 2      PAUMEN, GARY F
# 3     KOSLOW, CAROL M
# 4    PEDDER, DENNIS H
# ..                ...
# 95      SOWARD, IDA M
# 96   LAVINDER, JACK W
# 97       HUYNH, HAI H
# 98       HWU, DAVIS D
# 99       LEE, KEVIN L
#
# [100 rows x 7 columns]

# %% [markdown]
# The following bar shows the acceptance rate of the top 100 patent examiners at the PTO. It is interesting to note that the average acceptance rate for these examiners is almost 50%.

# %%
# Let's plot these numbers above in a nice bar plot
examiner_dec_df.plot.bar(stacked=True, x='examiner_full_name', figsize=(32, 8))
plt.title('Distribution of Accepted, Rejected, and Pending Patent Applications by USPTO Patent Examiners')
plt.xlabel('Examiner Name')
plt.ylabel('Number of Patent Applications')
plt.savefig('figures/basic_examiner_stats.png')
